# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file (change the path if needed)
df = pd.read_csv("/content/wheat-yield.csv")

df
# Out:
#            Country  Year  Wheat: Yield
# 0           Angola  1961        1.1111
# 1           Angola  1962        1.1111
# 2           Angola  1963        1.1111
# 3           Angola  1964        0.9286
# 4           Angola  1965        1.1111
# ..             ...   ...           ...
# 674  United States  2018        3.2005
# 675  United States  2019        3.4746
# 676  United States  2020        3.3417
# 677  United States  2021        2.9805
# 678  United States  2022        3.1273
#
# [679 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(12, 6))

# Create a line plot with Year on X-axis and Yield on Y-axis
sns.lineplot(data=df, x="Year", y="Wheat: Yield", hue="Country", alpha=0.7)

# Customize the plot
plt.title("Wheat Yield Over Time by Country", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Yield (tons per hectare)", fontsize=12)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

# Show the plot
plt.show()
